# %%
from langchain_community.document_loaders import GutenbergLoader


# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/100/pg100.txt").load() # All of Shakespeare
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/16328/pg16328.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/1232/pg1232.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/1184/pg1184.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/345/pg345.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/84/pg84.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/1342/pg1342.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/11/pg11.txt").load()
# full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/64317/pg64317.txt").load()


full_text = GutenbergLoader("https://www.gutenberg.org/cache/epub/345/pg345.txt").load()

print(f"{len(full_text[0].page_content)} characters in the doc")
# Out:
# 912764 characters in the doc

# %%
import requests
from IPython.display import Image, display

url = "https://www.gutenberg.org/cache/epub/345/images/cover.jpg"

response = requests.get(url)
display(Image(data=response.content))
